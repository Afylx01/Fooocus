# %% [markdown]
# # Lora Downloads in loras folder

# %%
#!wget -O /content/Fooocus/models/loras/Add-More-Details.safetensors https://civitai.com/api/download/models/87153?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/Detail-Tweaker-LoRA.safetensors https://civitai.com/api/download/models/62833
#!wget -O /content/Fooocus/models/loras/Studio-Ghibli-Style-LoRA.safetensors https://civitai.com/api/download/models/7657?type=Model&format=SafeTensor&size=full&fp=fp16
#!wget -O /content/Fooocus/models/loras/GHIBLI_Background.safetensors https://civitai.com/api/download/models/125985
#!wget -O /content/Fooocus/models/loras/KIDS-ILLUSTRATION.safetensors https://civitai.com/api/download/models/67980?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/Real-Mechanical-Parts.safetensors https://civitai.com/api/download/models/352237?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/SamDoesArts.safetensors https://civitai.com/api/download/models/7804?type=Model&format=SafeTensor&size=full&fp=fp16
#!wget -O /content/Fooocus/models/loras/xl_more_art-full.safetensors https://civitai.com/api/download/models/152309?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/Detail-Slider-LoRA.safetensors https://civitai.com/api/download/models/171989?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/GlowNeon-XL.safetensors https://civitai.com/api/download/models/348189?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/DreamArt.safetensors https://civitai.com/api/download/models/137124?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/Envy-Zoom-Slider.safetensors https://civitai.com/api/download/models/240274?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/Harrlogostext.safetensors https://civitai.com/api/download/models/214296
#!wget -O /content/Fooocus/models/loras/Texta.safetensors https://civitai.com/api/download/models/249521?type=Model&format=SafeTensor
#!wget -O /content/Fooocus/models/loras/sdxl_lightning_8step_lora.safetensors https://huggingface.co/ByteDance/SDXL-Lightning/resolve/main/sdxl_lightning_8step_lora.safetensors?download=true
#!wget -O /content/Fooocus/models/loras/Add-texts-XL.safetensors https://civitai.com/api/download/models/192961
#!wget -O /content/Fooocus/models/loras/Furry-Enhancer.safetensors https://huggingface.co/afylx/mohawk/resolve/main/Furry%20Enhancer%20V2.84.safetensors?download=true
# !wget -O /content/Fooocus/models/loras/MJ5-2.safetensors https://huggingface.co/afylx/mohawk/resolve/main/MJ52.safetensors?download=true

# %% [markdown]
# # Download the model you want to run.

# %%
#!wget -O /content/Fooocus/models/checkpoints/dreamshaperXL_v2TurboDpmppSDE_2.safetensors https://huggingface.co/afylx/mohawk/resolve/main/dreamshaperXL_v2TurboDpmppSDE_2.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/nightvisionXLPhotorealisticPortrait_v0791Bakedvae.safetensors https://civitai.com/api/download/models/247444?type=Model&format=SafeTensor&size=pruned&fp=fp16
#!wget -O /content/Fooocus/models/checkpoints/blue_pencil-XL-v5.0.0.safetensors https://huggingface.co/bluepen5805/blue_pencil-XL/resolve/main/blue_pencil-XL-v5.0.0.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/wowXL420_v420.safetensors http://tinyurl.com/56e6pwj9
#!wget -O /content/Fooocus/models/checkpoints/MorphXL.safetensors https://civitai.com/api/download/models/138966
#!wget -O /content/Fooocus/models/checkpoints/realcartoonXL_v6.safetensors https://huggingface.co/rafationgson/realcartoon-xl-v6/resolve/main/realcartoonXL_v6.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/MOHAWK_v20BackedVAE.safetensors https://huggingface.co/afylx/mohawk/resolve/main/MOHAWK_v20BackedVAE.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/counterfeitxl_v25.safetensors https://huggingface.co/afylx/mohawk/resolve/main/counterfeitxl_v25.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/copaxTimelessxlSDXL1_v10.safetensors https://huggingface.co/afylx/mohawk/resolve/main/copaxTimelessxlSDXL1_v10.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/Juggernaut_RunDiffusionPhoto2_Lightning_4Steps.safetensors https://huggingface.co/RunDiffusion/Juggernaut-XL-Lightning/resolve/main/Juggernaut_RunDiffusionPhoto2_Lightning_4Steps.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/Juggernaut-XL_v9_RunDiffusionPhoto_v2.safetensors https://huggingface.co/RunDiffusion/Juggernaut-XL-v9/resolve/main/Juggernaut-XL_v9_RunDiffusionPhoto_v2.safetensors
#!wget -O /content/Fooocus/models/checkpoints/protovisionXLHighFidelity3D.safetensors https://huggingface.co/afylx/mohawk/resolve/main/protovisionXLHighFidelity3D.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/blue_pencil-XL-v5.0.0-lightning.safetensors https://huggingface.co/bluepen5805/blue_pencil-XL/resolve/main/blue_pencil-XL-v5.0.0-lightning.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/AmalgamationXL-Lightning.safetensors https://civitai.com/api/download/models/365119
#!wget -O /content/Fooocus/models/checkpoints/dynavisionXLAllInOneStylized_releaseV0610Bakedvae.safetensors https://huggingface.co/afylx/mohawk/resolve/main/dynavisionXLAllInOneStylized_releaseV0610Bakedvae.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/FenrisXL.safetensors https://civitai.com/api/download/models/370565?type=Model&format=SafeTensor&size=full&fp=fp16
#!wget -O /content/Fooocus/models/checkpoints/anima_pencil-XL.safetensors https://civitai.com/api/download/models/370033
#!wget -O /content/Fooocus/models/checkpoints/ProteusV0.4-Lighting.safetensors https://huggingface.co/dataautogpt3/ProteusV0.4-Lightning/resolve/main/ProteusV0.4-Lighting.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/Proteus-RunDiffusion.safetensors https://huggingface.co/dataautogpt3/Proteus-RunDiffusion/resolve/main/Proteus-RunDiffusion.safetensors?download=true
#!wget -O /content/Fooocus/models/checkpoints/blue_pencil-XL-v6.0.0.safetensors https://huggingface.co/bluepen5805/blue_pencil-XL/resolve/main/blue_pencil-XL-v6.0.0.safetensors?download=true

# %%
import os
import urllib.parse

# Define the output path
output_path = "/content/Fooocus/models/checkpoints/"

# Define a list of URLs for each file
urls_to_download = [
    "https://huggingface.co/RunDiffusion/Juggernaut-X-v10/resolve/main/Juggernaut-X-RunDiffusion-NSFW.safetensors",
    #"https://civitai.com/api/download/models/247444?type=Model&format=SafeTensor&size=pruned&fp=fp16",
    # ... (list all other URLs)
]

# Generate and execute wget commands
for url in urls_to_download:
    # Parse the URL to extract the file name
    parsed_url = urllib.parse.urlparse(url)
    file_name = os.path.basename(parsed_url.path)
    
    # Execute the wget command
    os.system(f"wget -O {os.path.join(output_path, file_name)} {url}")

# Print a success message
print("All files have been downloaded successfully.")

# %% [markdown]
# #  Run Fooocus!

# %%
# %cd /content/Fooocus

# !python entry_with_update.py --share --always-high-vram
#!python entry_with_update.py --preset lightning01 --share --always-high-vram
#!python entry_with_update.py --preset mohawk --share --always-high-vram
#!python entry_with_update.py --preset mohawk1 --share --always-high-vram
#!python entry_with_update.py --preset copax --share --always-high-vram
#!python entry_with_update.py --preset anime --share --always-high-vram
#!python entry_with_update.py --preset realistic --share --always-high-vram
# Out:
#  67% 20/30 [00:17<00:08,  1.13it/s]

# %% [markdown]
# # Create Zip

# %%
# @title 7. Make zip of the outputs in here
import shutil

# Specify the path to the directory you want to zip
directory_path = '/content/Fooocus/outputs'

# Specify the path and name of the zip file to create
zip_file_path = '/content/outputs'

# Create a zip file
shutil.make_archive(zip_file_path, 'zip', directory_path)
